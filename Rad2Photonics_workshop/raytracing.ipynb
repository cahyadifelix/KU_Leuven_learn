# %%
from raytracing import *

path = ImagingPath()
path.objectHeight = 50
path.append(Space(d=300))
path.append(Lens(f=200, label = "f = 20 cm"))
path.append(Space(d=100))
path.append(Lens(f=100, label = "f = 10 cm"))
path.append(Space(d=200))
print(path.effectiveFocalLengths())
path.display(onlyPrincipalAndAxialRays=True)
# Out:
# FocalLengths(f1=100.0, f2=100.0)
# BeginnerHint [in figure.py]: No aperture stop in the system: cannot use onlyPrincipalAndAxialRays=True since they are not defined. Showing the default ObjectRays instead.
# UserWarning [in figure.py]: color is redundantly defined by the 'color' keyword argument and the fmt string "ko" (-> color='k'). The keyword argument will take precedence.
# MatplotlibDeprecationWarning [in figure.py]: The rectangles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Any custom property styling may be lost.
# MatplotlibDeprecationWarning [in figure.py]: The lines attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Any custom property styling may be lost.

# %%
path2 = ImagingPath()
path2.append(Space(d=30))
path2.append(Lens(f=10))
path2.append(Space(d=20))
#print(path.effectiveFocalLengths())
path2.display(onlyPrincipalAndAxialRays=True)
# Out:
# BeginnerHint [in figure.py]: Infinite field of view: cannot use limitObjectToFieldOfView=True. The object height is instead set to the default value of 10.0.
# BeginnerHint [in imagingpath.py]: Field of view is infinite. You can pass useObject=True to use the finite objectHeight.
# BeginnerHint [in figure.py]: No aperture stop in the system: cannot use onlyPrincipalAndAxialRays=True since they are not defined. Showing the default ObjectRays instead.
# UserWarning [in figure.py]: color is redundantly defined by the 'color' keyword argument and the fmt string "ko" (-> color='k'). The keyword argument will take precedence.
# MatplotlibDeprecationWarning [in figure.py]: The rectangles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Any custom property styling may be lost.
# ...
